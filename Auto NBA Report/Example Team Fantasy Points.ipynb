# %%
from fantasy_points import *

# %% [markdown]
# Enter 1 of 30 NBA team's nicknames into the function to see the team's player's last 10 performances (fantasy points).
#
# nickname example(s): Los Angeles Lakers -> Lakers; New York Knicks -> Knicks

# %%
team = "Hornets"
graphDetailedTeamPerformance(team)
