# %%
from fantasy import *

# %% [markdown]
# To generate a report of a team's player's last 10 performances, simply call the function "generateTeamReport("team_nick_name", "FanDuel/FD/DraftKings/DK")". A report is generated in the form of a pdf. Need a local folder named "Performances" to store temporary photos generated from player plots.
#
# Use FanDuel/FD for a report based on FanDuel's point calculations. Same reason for DraftKings/DK

# %%
generateTeamReport("Spurs", 'FD')

# %%
generateTeamReport("Spurs", 'DK')
